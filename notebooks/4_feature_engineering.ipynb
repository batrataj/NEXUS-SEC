# %% [markdown]
# <a href="https://colab.research.google.com/github/batrataj/NEXUS-SEC/blob/main/notebooks/4_feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/batrataj/NEXUS-SEC/main/data/clean_network_data.xlsx"

df = pd.read_excel(url)

df.head()
# Out:
#    Destination Port  Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0                80          38308                  1                       1
# 1               389            479                 11                       5
# 2                88           1095                 10                       6
# 3               389          15206                 17                      12
# 4                88           1092                  9                       6
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                            6                            6
# 1                          172                          326
# 2                         3150                         3150
# 3                         3452                         6660
# 4                         3150                         3152
#
#    Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Destination Port', 'Flow Duration', 'Total Fwd Packets',
#        'Total Backward Packets', 'Total Length of Fwd Packets',
#        'Total Length of Bwd Packets', 'Fwd Packet Length Max',
#        'Fwd Packet Length Min', 'Fwd Packet Length Mean',
#        'Fwd Packet Length Std', 'Label'],
#       dtype='object')

# %%
X = df.drop("Label", axis=1)
y = df["Label"]

# %%
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# %%
list(zip(encoder.classes_, range(len(encoder.classes_))))
# Out:
# [('BENIGN', 0)]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (793, 10)
# X_test shape: (199, 10)
# y_train shape: (793,)
# y_test shape: (199,)
