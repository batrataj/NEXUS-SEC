# %% [markdown]
# <a href="https://colab.research.google.com/github/batrataj/NEXUS-SEC/blob/main/notebooks/1_data_overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/batrataj/NEXUS-SEC/main/Wednesday-workingHours.pcap_ISCX.xlsx"

df = pd.read_excel(url)

df.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 80           38308                   1
# 1                389             479                  11
# 2                 88            1095                  10
# 3                389           15206                  17
# 4                 88            1092                   9
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        1                            6
# 1                        5                          172
# 2                        6                         3150
# 3                       12                         3452
# 4                        6                         3150
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             6                       6
# 1                           326                      79
# 2                          3150                    1575
# ...

# %%
df.shape
# Out:
# (999, 11)

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', ' Label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0    Destination Port             999 non-null    int64
#  1    Flow Duration                999 non-null    int64
#  2    Total Fwd Packets            999 non-null    int64
#  3    Total Backward Packets       999 non-null    int64
#  4   Total Length of Fwd Packets   999 non-null    int64
#  5    Total Length of Bwd Packets  999 non-null    int64
#  6    Fwd Packet Length Max        999 non-null    int64
#  7    Fwd Packet Length Min        999 non-null    int64
#  8    Fwd Packet Length Mean       999 non-null    float64
#  9    Fwd Packet Length Std        999 non-null    float64
#  10   Label                        999 non-null    object
# dtypes: float64(2), int64(8), object(1)
# memory usage: 86.0+ KB

# %%
df.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count         999.000000    9.990000e+02          999.000000
# mean         5767.329329    3.206594e+07          407.340340
# std         14412.264809    4.219467e+07         8620.770141
# min             0.000000    1.000000e+00            1.000000
# 25%            80.000000    1.013100e+04            2.000000
# 50%           135.000000    5.257736e+06            7.000000
# 75%           443.000000    6.604197e+07           14.000000
# max         59970.000000    1.199999e+08       203943.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count               999.000000                 9.990000e+02
# mean                516.609610                 5.370683e+03
# std               11067.475445                 5.401283e+04
# min                   0.000000                 0.000000e+00
# 25%                   1.000000                 3.850000e+01
# ...

# %%
df[' Label'].value_counts()
# Out:
#  Label
# BENIGN    999
# Name: count, dtype: int64
